# %%
import pandas as pd

df = pd.DataFrame(
    {
        "20cm": [20, 20, 20, 20, 20],
        "40cm": [40, 40, 40, 40, 40],
        "60cm": [60, 60, 60, 60, 60],
        "80cm": [80, 80, 80, 80, 80],
        # "Drive Square-Pattern Error (cm)": [0,0,0,0,0]
    }, index=["Run #1", "Run #2", "Run #3", "Run #4", "Run #5"]
)
df_desc = df.describe()
df.append(df_desc)
# Out:
#         20cm  40cm  60cm  80cm
# Run #1  20.0  40.0  60.0  80.0
# Run #2  20.0  40.0  60.0  80.0
# Run #3  20.0  40.0  60.0  80.0
# Run #4  20.0  40.0  60.0  80.0
# Run #5  20.0  40.0  60.0  80.0
# count    5.0   5.0   5.0   5.0
# mean    20.0  40.0  60.0  80.0
# std      0.0   0.0   0.0   0.0
# min     20.0  40.0  60.0  80.0
# 25%     20.0  40.0  60.0  80.0
# 50%     20.0  40.0  60.0  80.0
# 75%     20.0  40.0  60.0  80.0
# max     20.0  40.0  60.0  80.0

# %%
df.plot(style='x')
